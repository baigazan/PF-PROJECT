# %% [markdown]
# GITHUB:
# https://github.com/baigazan/PF-PROJECT

# %%
import pandas as pd

# %%
df = pd.read_csv("seattle-weather.csv")

# %%
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
df.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
df.head(10)
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain
# 5  2012-01-06            2.5       4.4       2.2   2.2     rain
# 6  2012-01-07            0.0       7.2       2.8   2.3     rain
# 7  2012-01-08            0.0      10.0       2.8   2.0      sun
# 8  2012-01-09            4.3       9.4       5.0   3.4     rain
# 9  2012-01-10            1.0       6.1       0.6   3.4     rain

# %%
df.tail()
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 1456  2015-12-27            8.6       4.4       1.7   2.9    rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3    rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6     fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4     sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5     sun

# %%
df.tail(10)
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 1451  2015-12-22            4.6       7.8       2.8   5.0    rain
# 1452  2015-12-23            6.1       5.0       2.8   7.6    rain
# 1453  2015-12-24            2.5       5.6       2.2   4.3    rain
# 1454  2015-12-25            5.8       5.0       2.2   1.5    rain
# 1455  2015-12-26            0.0       4.4       0.0   2.5     sun
# 1456  2015-12-27            8.6       4.4       1.7   2.9    rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3    rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6     fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4     sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5     sun

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
df.describe()
# Out:
#        precipitation     temp_max     temp_min         wind
# count    1461.000000  1461.000000  1461.000000  1461.000000
# mean        3.029432    16.439083     8.234771     3.241136
# std         6.680194     7.349758     5.023004     1.437825
# min         0.000000    -1.600000    -7.100000     0.400000
# 25%         0.000000    10.600000     4.400000     2.200000
# 50%         0.000000    15.600000     8.300000     3.000000
# 75%         2.800000    22.200000    12.200000     4.000000
# max        55.900000    35.600000    18.300000     9.500000

# %%
df.describe(include="all")
# Out:
#               date  precipitation     temp_max     temp_min         wind  \
# count         1461    1461.000000  1461.000000  1461.000000  1461.000000
# unique        1461            NaN          NaN          NaN          NaN
# top     2012-01-01            NaN          NaN          NaN          NaN
# freq             1            NaN          NaN          NaN          NaN
# mean           NaN       3.029432    16.439083     8.234771     3.241136
# std            NaN       6.680194     7.349758     5.023004     1.437825
# min            NaN       0.000000    -1.600000    -7.100000     0.400000
# 25%            NaN       0.000000    10.600000     4.400000     2.200000
# 50%            NaN       0.000000    15.600000     8.300000     3.000000
# 75%            NaN       2.800000    22.200000    12.200000     4.000000
# max            NaN      55.900000    35.600000    18.300000     9.500000
#
#        weather
# count     1461
# unique       5
# top       rain
# freq       641
# ...

# %%
df.shape
# Out:
# (1461, 6)

# %%
df.columns
# Out:
# Index(['date', 'precipitation', 'temp_max', 'temp_min', 'wind', 'weather'], dtype='object')

# %%
df['weather'].max()
# Out:
# 'sun'

# %%
df['weather'].min()
# Out:
# 'drizzle'

# %%
df['temp_max'].idxmax()
# Out:
# 953

# %%
df['temp_max'].loc[953]
# Out:
# 35.6

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# 1460    False
# Length: 1461, dtype: bool

# %%
df.sample(10)
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 757   2014-01-27            0.0       9.4       1.7   1.3     sun
# 442   2013-03-18            0.0      11.7       3.9   5.9    rain
# 954   2014-08-12           12.7      27.2      17.2   3.1    rain
# 1013  2014-10-10            0.3      18.3      10.0   3.8    rain
# 787   2014-02-26            0.0      13.9       5.6   2.5     sun
# 1107  2015-01-12            0.0      11.1       4.4   1.6     fog
# 1002  2014-09-29            0.8      16.7      11.1   3.5    rain
# 471   2013-04-16            0.3      13.9       3.3   2.6    rain
# 323   2012-11-19           54.1      13.3       8.3   6.0    rain
# 867   2014-05-17            0.0      20.0      11.7   3.2     sun

# %%
hello = df[["weather","wind"]]
print(hello)
# Out:
#       weather  wind
# 0     drizzle   4.7
# 1        rain   4.5
# 2        rain   2.3
# 3        rain   4.7
# 4        rain   6.1
# ...       ...   ...
# 1456     rain   2.9
# 1457     rain   1.3
# 1458      fog   2.6
# 1459      sun   3.4
# 1460      sun   3.5
#
# [1461 rows x 2 columns]

# %%
df.loc[0:5]
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain
# 5  2012-01-06            2.5       4.4       2.2   2.2     rain

# %%
df.loc[ :,'weather']
# Out:
# 0       drizzle
# 1          rain
# 2          rain
# 3          rain
# 4          rain
#          ...
# 1456       rain
# 1457       rain
# 1458        fog
# 1459        sun
# 1460        sun
# Name: weather, Length: 1461, dtype: object

# %%
data = df.loc[0:5]
data.loc[1,'wind',] = 6
data
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   6.0     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain
# 5  2012-01-06            2.5       4.4       2.2   2.2     rain

# %%
df.iloc[3, 4]
# Out:
# 4.7

# %%
df.iloc[:3,:4]
# Out:
#          date  precipitation  temp_max  temp_min
# 0  2012-01-01            0.0      12.8       5.0
# 1  2012-01-02           10.9      10.6       2.8
# 2  2012-01-03            0.8      11.7       7.2

# %%
df[df["weather"] == "rain"]
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 1     2012-01-02           10.9      10.6       2.8   4.5    rain
# 2     2012-01-03            0.8      11.7       7.2   2.3    rain
# 3     2012-01-04           20.3      12.2       5.6   4.7    rain
# 4     2012-01-05            1.3       8.9       2.8   6.1    rain
# 5     2012-01-06            2.5       4.4       2.2   2.2    rain
# ...          ...            ...       ...       ...   ...     ...
# 1452  2015-12-23            6.1       5.0       2.8   7.6    rain
# 1453  2015-12-24            2.5       5.6       2.2   4.3    rain
# 1454  2015-12-25            5.8       5.0       2.2   1.5    rain
# 1456  2015-12-27            8.6       4.4       1.7   2.9    rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3    rain
#
# [641 rows x 6 columns]

# %%
df.fillna(0)
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
df.drop(columns="date")
# Out:
#       precipitation  temp_max  temp_min  wind  weather
# 0               0.0      12.8       5.0   4.7  drizzle
# 1              10.9      10.6       2.8   4.5     rain
# 2               0.8      11.7       7.2   2.3     rain
# 3              20.3      12.2       5.6   4.7     rain
# 4               1.3       8.9       2.8   6.1     rain
# ...             ...       ...       ...   ...      ...
# 1456            8.6       4.4       1.7   2.9     rain
# 1457            1.5       5.0       1.7   1.3     rain
# 1458            0.0       7.2       0.6   2.6      fog
# 1459            0.0       5.6      -1.0   3.4      sun
# 1460            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 5 columns]

# %%
df.drop(index=[1,2])
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# 5     2012-01-06            2.5       4.4       2.2   2.2     rain
# 6     2012-01-07            0.0       7.2       2.8   2.3     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1459 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %%
df['wind'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# 1460    False
# Name: wind, Length: 1461, dtype: bool

# %%
df['weather'].max()
# Out:
# 'sun'

# %%
df.dropna()
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
df.replace(0.0, "Missing")
# Out:
#             date precipitation temp_max temp_min  wind  weather
# 0     2012-01-01       Missing     12.8      5.0   4.7  drizzle
# 1     2012-01-02          10.9     10.6      2.8   4.5     rain
# 2     2012-01-03           0.8     11.7      7.2   2.3     rain
# 3     2012-01-04          20.3     12.2      5.6   4.7     rain
# 4     2012-01-05           1.3      8.9      2.8   6.1     rain
# ...          ...           ...      ...      ...   ...      ...
# 1456  2015-12-27           8.6      4.4      1.7   2.9     rain
# 1457  2015-12-28           1.5      5.0      1.7   1.3     rain
# 1458  2015-12-29       Missing      7.2      0.6   2.6      fog
# 1459  2015-12-30       Missing      5.6     -1.0   3.4      sun
# 1460  2015-12-31       Missing      5.6     -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
name_change = df.rename(columns={'wind':'breeze'})
print(name_change)
# Out:
#             date  precipitation  temp_max  temp_min  breeze  weather
# 0     2012-01-01            0.0      12.8       5.0     4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8     4.5     rain
# 2     2012-01-03            0.8      11.7       7.2     2.3     rain
# 3     2012-01-04           20.3      12.2       5.6     4.7     rain
# 4     2012-01-05            1.3       8.9       2.8     6.1     rain
# ...          ...            ...       ...       ...     ...      ...
# 1456  2015-12-27            8.6       4.4       1.7     2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7     1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6     2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0     3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1     3.5      sun
#
# [1461 rows x 6 columns]

# %%
df.groupby('date')['temp_max'].mean()
# Out:
# date
# 2012-01-01    12.8
# 2012-01-02    10.6
# 2012-01-03    11.7
# 2012-01-04    12.2
# 2012-01-05     8.9
#               ...
# 2015-12-27     4.4
# 2015-12-28     5.0
# 2015-12-29     7.2
# 2015-12-30     5.6
# 2015-12-31     5.6
# Name: temp_max, Length: 1461, dtype: float64

# %%
df.sort_values("wind")
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 661   2013-10-23            0.0      12.8       6.1   0.4     sun
# 725   2013-12-26            0.0       6.7       0.6   0.5     sun
# 1105  2015-01-10            5.8       7.8       6.1   0.5    rain
# 694   2013-11-25            0.0      12.2       2.2   0.5     sun
# 662   2013-10-24            0.0      10.0       6.1   0.6     sun
# ...          ...            ...       ...       ...   ...     ...
# 418   2013-02-22            9.4       7.8       3.9   8.1    rain
# 20    2012-01-21            3.0       8.3       3.3   8.2    rain
# 741   2014-01-11           21.3      14.4       7.2   8.8    rain
# 700   2013-12-01            3.0      13.3       7.8   8.8    rain
# 351   2012-12-17            2.0       8.3       1.7   9.5    rain
#
# [1461 rows x 6 columns]

# %%
df['wind'].sum()
# Out:
# 4735.3

# %%
df['precipitation'].count()
# Out:
# 1461

# %%
df["wind"].mean()
# Out:
# 3.24113620807666

# %%
df["temp_max"].mode()
# Out:
# 0    11.1
# Name: temp_max, dtype: float64

# %%
df["temp_min"].median()
# Out:
# 8.3

# %%
df['wind'].value_counts()
# Out:
# wind
# 2.6    76
# 3.0    65
# 2.2    55
# 2.5    51
# 2.8    47
#        ..
# 0.4     1
# 9.5     1
# 6.9     1
# 8.2     1
# 7.7     1
# Name: count, Length: 79, dtype: int64

# %%
df['normal_temp'] = 6
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather  \
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   6.0     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#       normal_temp
# 0               6
# 1               6
# 2               6
# 3               6
# 4               6
# ...           ...
# 1456            6
# ...

# %%
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   6.0     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# 5     2012-01-06            2.5       4.4       2.2   2.2     rain
# 6     2012-01-07            0.0       7.2       2.8   2.3     rain
# 7     2012-01-08            0.0      10.0       2.8   2.0      sun
# 8     2012-01-09            4.3       9.4       5.0   3.4     rain
# 9     2012-01-10            1.0       6.1       0.6   3.4     rain
# 10    2012-01-11            0.0       6.1      -1.1   5.1      sun
# 11    2012-01-12            0.0       6.1      -1.7   1.9      sun
# 12    2012-01-13            0.0       5.0      -2.8   1.3      sun
# ...

# %%
pd.reset_option("display.max_rows")
pd.reset_option("display.max_columns")

# %%
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
df.plot(kind='line')
# Out:
# <Axes: >

# %%
data = df['temp_max'].loc[0:10]
data.plot(kind='bar',color='red',title='temperature max')
# Out:
# <Axes: title={'center': 'temperature max'}>

# %%
data = df.loc[0:10,'wind']
data.value_counts().plot(kind='barh',color='green',title='wind count')
# Out:
# <Axes: title={'center': 'wind count'}, ylabel='wind'>

# %%
df['temp_min'].plot(kind='hist',title='Minimum temperature',color='blue')
# Out:
# <Axes: title={'center': 'Minimum temperature'}, ylabel='Frequency'>

# %%
data = df.loc[0:10,'precipitation'] 
data.value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['temp_max'].plot(kind='box',title='maximum temperature',color='brown')
# Out:
# <Axes: title={'center': 'maximum temperature'}>

# %%
df.plot(kind='scatter', x='date', y='weather',color='black',title='weather display')
# Out:
# <Axes: title={'center': 'weather display'}, xlabel='date', ylabel='weather'>

# %%
df['wind'].plot(kind='area',color='purple',title='Wind_area')
# Out:
# <Axes: title={'center': 'Wind_area'}>

# %%
df.to_csv("output.csv")
